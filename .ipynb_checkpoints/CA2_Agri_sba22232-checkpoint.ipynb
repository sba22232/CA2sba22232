# %% [markdown]
# # CA2 AgriData Assignment 2022/23 for sba22232

# %% [markdown]
# ## Going to import the libaries I plan on using through my assignment first -

# %%
import pandas as pd # for the Exploratory Data analysis
import numpy as np # for any numerical calculations that i will use
import seaborn as sns # for my visualisations of the data
import matplotlib.pyplot as plt # for my visualisations of the data
import missingno as msno 
import plotly.io as pio
pio.renderers.default = 'browser'
import panel as pn
pn.extension('tabulator')
pn.extension(sizing_mode='stretch_width')
import holoviews as hv
import hvplot.pandas
import json
import plotly.express as px
from scipy import stats
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## My Project Plan and Timeline

# %%
# Reads my GANTT Image into the notebook
from IPython.display import Image
Image(filename =r'GANTT.png', width = 900, height = 400)

# %% [markdown]
# ## Reading Datasets and naming of the new Dataframes

# %%
# Reading first dataset into my initial Dataframe using pandas
# My first dataset is the Dairy production volume data for each country in the EU from 1961 to 2019 and my naming choice for this dataframe is based on Dairy Production so "dprod"
dprod = pd.read_csv('FAOSTAT_data_en_12-17-2022.csv');

# My second dataset is the Dairy import, export and Value data for each country in the EU from 2010 to 2020
# As with above my naming choice for this dataframe is based on Dairy Import, Export and Value so "diev"
diev = pd.read_csv('FAOSTAT_data_en_12-17-2022-1.csv');

# %% [markdown]
# # 1.	Structural investigation
#
# ## Here I am going to focus on the data clean up and analysis of the two datasets, both will prepared in tandem.
#
# ## I use the .head() to review the first 5 columns of the dataset to get an understanding of columns and type of data included. I will also have a look at the different data types to ensure they are recorded correctly and give me chance to correct any incorrect types now.
#
# ## The .select_dtypes(exclude="number").head() and .describe(exclude="number") enables me to dive deeper into the different types of non numerical available in my datasets. I can see the most frequent entry and volumes of the categorical data.

# %%
# Displays the first 5 rows of the dataset
dprod.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)     Area  \
# 0         QCL  Crops and livestock products                8  Albania
# 1         QCL  Crops and livestock products                8  Albania
# 2         QCL  Crops and livestock products                8  Albania
# 3         QCL  Crops and livestock products                8  Albania
# 4         QCL  Crops and livestock products                8  Albania
#
#    Element Code     Element  Item Code (CPC)                Item  Year Code  \
# 0          5510  Production         22241.01  Butter of cow milk       1961
# 1          5510  Production         22241.01  Butter of cow milk       1962
# 2          5510  Production         22241.01  Butter of cow milk       1963
# 3          5510  Production         22241.01  Butter of cow milk       1964
# 4          5510  Production         22241.01  Butter of cow milk       1965
#
#    Year    Unit   Value Flag Flag Description
# 0  1961  tonnes   880.0    E  Estimated value
# 1  1962  tonnes   900.0    E  Estimated value
# 2  1963  tonnes   960.0    E  Estimated value
# 3  1964  tonnes  1000.0    E  Estimated value
# 4  1965  tonnes  1100.0    E  Estimated value

# %%
# Displays only non-numerical data for the first 5 rows of the dataset 
dprod.select_dtypes(exclude="number").head()
# Out:
#   Domain Code                        Domain     Area     Element  \
# 0         QCL  Crops and livestock products  Albania  Production
# 1         QCL  Crops and livestock products  Albania  Production
# 2         QCL  Crops and livestock products  Albania  Production
# 3         QCL  Crops and livestock products  Albania  Production
# 4         QCL  Crops and livestock products  Albania  Production
#
#                  Item    Unit Flag Flag Description
# 0  Butter of cow milk  tonnes    E  Estimated value
# 1  Butter of cow milk  tonnes    E  Estimated value
# 2  Butter of cow milk  tonnes    E  Estimated value
# 3  Butter of cow milk  tonnes    E  Estimated value
# 4  Butter of cow milk  tonnes    E  Estimated value

# %%
# Displays how many unique values for each non-numerical feature and the frequency of the most common value
dprod.describe(exclude="number")
# Out:
#        Domain Code                        Domain    Area     Element  \
# count        22847                         22847   22847       22847
# unique           1                             1      45           1
# top            QCL  Crops and livestock products  Europe  Production
# freq         22847                         22847    1325       22847
#
#                       Item    Unit   Flag Flag Description
# count                22847   22847  22847            22847
# unique                  23       1      5                5
# top     Butter of cow milk  tonnes      A  Official figure
# freq                  1862   22847   8880             8880

# %%
# Displays the first 5 rows of the dataset
diev.head()
# Out:
#   Domain Code                 Domain  Reporter Country Code (M49)  \
# 0          TM  Detailed trade matrix                            8
# 1          TM  Detailed trade matrix                            8
# 2          TM  Detailed trade matrix                            8
# 3          TM  Detailed trade matrix                            8
# 4          TM  Detailed trade matrix                            8
#
#   Reporter Countries  Partner Country Code (M49) Partner Countries  \
# 0            Albania                          40           Austria
# 1            Albania                          40           Austria
# 2            Albania                          40           Austria
# 3            Albania                          40           Austria
# 4            Albania                          40           Austria
#
#    Element Code          Element  Item Code (FAO)  \
# 0          5610  Import Quantity              886
# 1          5610  Import Quantity              886
# 2          5622     Import Value              886
# 3          5622     Import Value              886
# 4          5610  Import Quantity              893
#
#                                      Item  Year Code  Year      Unit  Value  \
# 0                      Butter of cow milk       2012  2012    tonnes    2.0
# 1                      Butter of cow milk       2013  2013    tonnes    2.0
# 2                      Butter of cow milk       2012  2012  1000 US$    6.0
# 3                      Butter of cow milk       2013  2013  1000 US$    9.0
# 4  Buttermilk, curdled and acidified milk       2010  2010    tonnes    0.0
#
#   Flag Flag Description
# 0    A  Official figure
# 1    A  Official figure
# 2    A  Official figure
# 3    A  Official figure
# 4    A  Official figure

# %%
# Displays only non-numerical data for the first 5 rows of the dataset 
diev.select_dtypes(exclude="number").head()
# Out:
#   Domain Code                 Domain Reporter Countries Partner Countries  \
# 0          TM  Detailed trade matrix            Albania           Austria
# 1          TM  Detailed trade matrix            Albania           Austria
# 2          TM  Detailed trade matrix            Albania           Austria
# 3          TM  Detailed trade matrix            Albania           Austria
# 4          TM  Detailed trade matrix            Albania           Austria
#
#            Element                                    Item      Unit Flag  \
# 0  Import Quantity                      Butter of cow milk    tonnes    A
# 1  Import Quantity                      Butter of cow milk    tonnes    A
# 2     Import Value                      Butter of cow milk  1000 US$    A
# 3     Import Value                      Butter of cow milk  1000 US$    A
# 4  Import Quantity  Buttermilk, curdled and acidified milk    tonnes    A
#
#   Flag Description
# 0  Official figure
# 1  Official figure
# 2  Official figure
# 3  Official figure
# 4  Official figure

# %%
# Displays how many unique values for each non-numerical feature and the frequency of the most common value
diev.describe(exclude="number")
# Out:
#        Domain Code                 Domain Reporter Countries  \
# count       232646                 232646             232646
# unique           1                      1                 40
# top             TM  Detailed trade matrix            Germany
# freq        232646                 232646              13922
#
#        Partner Countries          Element                        Item    Unit  \
# count             232646           232646                      232646  232646
# unique                27                4                          18       2
# top              Germany  Import Quantity  Cheese from whole cow milk  tonnes
# freq               17910            59412                       29640  116323
#
#           Flag Flag Description
# count   232646           232646
# unique       4                4
# top          A  Official figure
# freq    231402           231402

# %% [markdown]
# ### After having reviewed the non numerical features, I want to take a look at what numerical data I have and whether it is binary or ordinal or continous

# %%
# For each numerical feature compute number of unique entries
unique_values = dprod.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %%
# For each numerical feature compute number of unique entries
unique_values = diev.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar(logy=True, figsize=(15, 4), title="Unique values per feature");

# %% [markdown]
# ## Here I use .info() to give me similar insights to above for the data types for the columns in the dataset.

# %%
# Displays the column name, count and data type 
dprod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22847 entries, 0 to 22846
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       22847 non-null  object
#  1   Domain            22847 non-null  object
#  2   Area Code (M49)   22847 non-null  int64
#  3   Area              22847 non-null  object
#  4   Element Code      22847 non-null  int64
#  5   Element           22847 non-null  object
#  6   Item Code (CPC)   22847 non-null  float64
#  7   Item              22847 non-null  object
#  8   Year Code         22847 non-null  int64
#  9   Year              22847 non-null  int64
#  10  Unit              22847 non-null  object
#  11  Value             21464 non-null  float64
#  12  Flag              22847 non-null  object
#  13  Flag Description  22847 non-null  object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 2.4+ MB

# %%
# Displays the column name, count and data type 
diev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232646 entries, 0 to 232645
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Domain Code                  232646 non-null  object
#  1   Domain                       232646 non-null  object
#  2   Reporter Country Code (M49)  232646 non-null  int64
#  3   Reporter Countries           232646 non-null  object
#  4   Partner Country Code (M49)   232646 non-null  int64
#  5   Partner Countries            232646 non-null  object
#  6   Element Code                 232646 non-null  int64
#  7   Element                      232646 non-null  object
#  8   Item Code (FAO)              232646 non-null  int64
#  9   Item                         232646 non-null  object
#  10  Year Code                    232646 non-null  int64
#  11  Year                         232646 non-null  int64
#  12  Unit                         232646 non-null  object
#  13  Value                        232304 non-null  float64
#  14  Flag                         232646 non-null  object
#  15  Flag Description             232646 non-null  object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 28.4+ MB

# %% [markdown]
# ## Here I use .shape() to show me the number of rows and columns in both datasets.

# %%
# Displays the number or rows and columns in the dataset
dprod.shape
# Out:
# (22847, 14)

# %%
# Displays the number or rows and columns in the dataset
diev.shape
# Out:
# (232646, 16)

# %% [markdown]
# ## Here I use .columns to show me the headings of columns in both datasets.
# This allows me to see comparisons or similar columns headings within the two datasets as my ultimate goal is to merge the datasets to improve the data mix for analysis later.
#
# The reason for merging the datasets is down to the type of information. The dprod dataset has production values in Tonnes for the products whereas the diev dataset has both quanitity in Tonnes and Value in Dollars for both the Import and Export activities for the products. By having the two different types of information aligned gives me more options for analysis.

# %%
dprod.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
diev.columns
# Out:
# Index(['Domain Code', 'Domain', 'Reporter Country Code (M49)',
#        'Reporter Countries', 'Partner Country Code (M49)', 'Partner Countries',
#        'Element Code', 'Element', 'Item Code (FAO)', 'Item', 'Year Code',
#        'Year', 'Unit', 'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %% [markdown]
# ## Qualitative Investigation
#
# ### Here I use following 3 functions to help me understand how many duplicate, unique and null entries for the datasets
# - .duplicated().sum() - Gives the number of Duplicated rows in the dataset
# - .nunique - Gives the volume of unique entries per column
# - msno.matrix - This plot shows the completeness of the data and visualises where the data is missing from
# - .isnull().sum() - Gives the number of Null or NaN values in the columns
# I will run all 3 against each dataset and decide the impact of each after i have all of them complete.

# %%
# Checks number of duplicates in the dataset
dprod.duplicated().sum()
# Out:
# 0

# %%
# Checks number of duplicates in the dataset
diev.duplicated().sum()
# Out:
# 0

# %%
# Displays the number of unique values in the dataset
dprod.nunique()
# Out:
# Domain Code             1
# Domain                  1
# Area Code (M49)        45
# Area                   45
# Element Code            1
# Element                 1
# Item Code (CPC)        23
# Item                   23
# Year Code              59
# Year                   59
# Unit                    1
# Value               12357
# Flag                    5
# Flag Description        5
# dtype: int64

# %%
# Displays the number of unique values in the dataset
diev.nunique()
# Out:
# Domain Code                        1
# Domain                             1
# Reporter Country Code (M49)       40
# Reporter Countries                40
# Partner Country Code (M49)        27
# Partner Countries                 27
# Element Code                       4
# Element                            4
# Item Code (FAO)                   18
# Item                              18
# Year Code                         11
# Year                              11
# Unit                               2
# Value                          23282
# Flag                               4
# Flag Description                   4
# dtype: int64

# %%
# Displays the completeness of the dataset and where the missing values are
msno.matrix(dprod, labels=True, sort="descending");

# %%
# Displays the completeness of the dataset and where the missing values are
msno.matrix(diev, labels=True, sort="descending");

# %%
# Displays the count of missing or null values in the data
dprod.isnull().sum()
# Out:
# Domain Code            0
# Domain                 0
# Area Code (M49)        0
# Area                   0
# Element Code           0
# Element                0
# Item Code (CPC)        0
# Item                   0
# Year Code              0
# Year                   0
# Unit                   0
# Value               1383
# Flag                   0
# Flag Description       0
# dtype: int64

# %%
# Displays the count of missing or null values in the data
diev.isnull().sum()
# Out:
# Domain Code                      0
# Domain                           0
# Reporter Country Code (M49)      0
# Reporter Countries               0
# Partner Country Code (M49)       0
# Partner Countries                0
# Element Code                     0
# Element                          0
# Item Code (FAO)                  0
# Item                             0
# Year Code                        0
# Year                             0
# Unit                             0
# Value                          342
# Flag                             0
# Flag Description                 0
# dtype: int64

# %% [markdown]
# ## Plotting out the datasets to help identify trends or unwanted data in the dataset i.e. they dont add value to the analysis

# %%
# Displays a global view of the dataset for only numerical features
dprod.plot(lw=0, marker=".", subplots=True, layout=(-1, 4),
          figsize=(15, 30), markersize=1);

# %%
# Displays a global view of the dataset for only numerical features
diev.plot(lw=0, marker=".", subplots=True, layout=(-1, 4),
          figsize=(15, 30), markersize=1);

# %%
# Displays a global view of the dataset for non numerical features by excluding the numerical entries
# Create figure object with 3 subplots
fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(26, 16))

# Identify non-numerical features
df_non_numerical = dprod.select_dtypes(exclude=["number", "datetime"])

# Loop through features and put each subplot on a matplotlib axis object
for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of occurrences per unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=0, marker=".", ax=ax)
    
plt.show();

# %%
# Displays a global view of the dataset for non numerical features by excluding the numerical entries
# Create figure object with 3 subplots
fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(26, 16))

# Identify non-numerical features
df_non_numerical = diev.select_dtypes(exclude=["number", "datetime"])

# Loop through features and put each subplot on a matplotlib axis object
for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of occurrences per unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=0, marker=".", ax=ax)
    
plt.show();

# %% [markdown]
# ### Now we know there are no Duplicated Values, plenty of unique values within the features and we will deal with the Null Values later in the prepartion as I need to review more aspects of the data to decide whether or not to remove them. Currently i dont believe to them statistically significant.

# %% [markdown]
# ### Next I want to do is remove the columns that dont add value overall to the analysis e.g. Columns with only one distinct value. This will begin prepare the dataset to be combined.
# - Domain Code
# - Domain
# - Element Code
# - Area Code
# - Year Code
#
# For examle - We know the "Domain" is for Production in Crops and livestock products based on the data contained and having their code types will only bulk the data unnecessscarily.

# %%
# Selects and drops the listed columns and removes any year before 2010 from the dataset
# Then when complete, displays the top 5 rows of the dataset
dprod.drop(['Domain Code', 
            'Item Code (CPC)',
            'Area Code (M49)', 
            'Year Code', 
            'Domain', 
            'Element Code', 
            'Flag'], axis=1, inplace=True)
dprod.drop(dprod[dprod['Year'] <= 2009].index, inplace = True)
dprod.head()
# Out:
#        Area     Element                Item  Year    Unit   Value  \
# 49  Albania  Production  Butter of cow milk  2010  tonnes  3100.0
# 50  Albania  Production  Butter of cow milk  2011  tonnes  3200.0
# 51  Albania  Production  Butter of cow milk  2012  tonnes  3500.0
# 52  Albania  Production  Butter of cow milk  2013  tonnes  3700.0
# 53  Albania  Production  Butter of cow milk  2014  tonnes  4500.0
#
#    Flag Description
# 49  Official figure
# 50  Official figure
# 51  Official figure
# 52  Official figure
# 53  Official figure

# %%
# Selects and drops the listed columns, changes the name of the 'Reporter Countries' column to 'Area' and removes the year 2020 from the dataset
# Then when complete, displays the top 5 rows of the dataset
diev.drop(['Domain Code',
           'Domain',
           'Element Code',
           'Reporter Country Code (M49)',
           'Partner Country Code (M49)',
           'Partner Countries',
           'Item Code (FAO)',
           'Year Code',
           'Flag'], axis=1, inplace=True)
diev.rename(columns = {'Reporter Countries':'Area'}, inplace = True)
diev.drop(diev[diev['Year'] >= 2020].index, inplace = True)
diev.head()
# Out:
#       Area          Element                                    Item  Year  \
# 0  Albania  Import Quantity                      Butter of cow milk  2012
# 1  Albania  Import Quantity                      Butter of cow milk  2013
# 2  Albania     Import Value                      Butter of cow milk  2012
# 3  Albania     Import Value                      Butter of cow milk  2013
# 4  Albania  Import Quantity  Buttermilk, curdled and acidified milk  2010
#
#        Unit  Value Flag Description
# 0    tonnes    2.0  Official figure
# 1    tonnes    2.0  Official figure
# 2  1000 US$    6.0  Official figure
# 3  1000 US$    9.0  Official figure
# 4    tonnes    0.0  Official figure

# %% [markdown]
# ## Now the two data sets match in terms of data types and structure, its time to combine them and I will use the pd.concat() function to add the diev dataset to the end of the dprod dataset.

# %%
# Concatenates the two datasets into one new Dataframe and once complete displays the end of the dataframe to show the data has moved
df = pd.concat([dprod, diev], ignore_index=True)

df.tail()
# Out:
#                                                      Area       Element  \
# 213704  United Kingdom of Great Britain and Northern I...  Export Value
# 213705  United Kingdom of Great Britain and Northern I...  Export Value
# 213706  United Kingdom of Great Britain and Northern I...  Export Value
# 213707  United Kingdom of Great Britain and Northern I...  Export Value
# 213708  United Kingdom of Great Britain and Northern I...  Export Value
#
#                           Item  Year      Unit  Value Flag Description
# 213704  Whole milk, evaporated  2015  1000 US$    2.0  Official figure
# 213705  Whole milk, evaporated  2016  1000 US$    7.0  Official figure
# 213706  Whole milk, evaporated  2017  1000 US$    0.0  Official figure
# 213707  Whole milk, evaporated  2018  1000 US$    5.0  Official figure
# 213708  Whole milk, evaporated  2019  1000 US$    7.0  Official figure

# %% [markdown]
# ## Now we have a new Dataframe, we need to complete some of the previous steps to ensure everything worked as expected.

# %%
# Checks the unique entries for Year to ensure only the 10 years expected appears.
df['Year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
# Displays the number or rows and columns in the dataset
df.shape
# Out:
# (213709, 7)

# %% [markdown]
# ## The number of columns has reduced from 14 to 7 and appears cleaner. Next I will review and remove Null or unavailable data.

# %%
# Checking the Null values of the dataframe
df.isnull().sum()
# Out:
# Area                  0
# Element               0
# Item                  0
# Year                  0
# Unit                  0
# Value               461
# Flag Description      0
# dtype: int64

# %%
# Displays the completeness of the dataset and where the missing values are
msno.matrix(df, labels=True, sort="descending");

# %%
# Displays a global view of the dataset for only numerical features
dprod.plot(lw=0, marker=".", subplots=True, layout=(-1, 4),
          figsize=(15, 30), markersize=1);

# %%
# Displays a global view of the dataset for non numerical features by excluding the numerical entries
# Create figure object with 3 subplots
fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(22, 16))

# Identify non-numerical features
df_non_numerical = df.select_dtypes(exclude=["number", "datetime"])

# Loop through features and put each subplot on a matplotlib axis object
for col, ax in zip(df_non_numerical.columns, axes.ravel()):

    # Selects one single feature and counts number of occurrences per unique value
    df_non_numerical[col].value_counts().plot(

        # Plots this information in a figure with log-scaled y-axis
        logy=True, title=col, lw=1, marker=".", ax=ax)
    
plt.show();

# %%
# Displays Values equal to Zero in the dataframe
df[df['Value'] == 0]
# Out:
#                                                      Area          Element  \
# 166                                               Austria       Production
# 167                                               Austria       Production
# 168                                               Austria       Production
# 169                                               Austria       Production
# 170                                               Austria       Production
# ...                                                   ...              ...
# 213674  United Kingdom of Great Britain and Northern I...  Export Quantity
# 213692  United Kingdom of Great Britain and Northern I...  Export Quantity
# 213693  United Kingdom of Great Britain and Northern I...  Export Quantity
# 213696  United Kingdom of Great Britain and Northern I...  Export Quantity
# 213706  United Kingdom of Great Britain and Northern I...     Export Value
#
#                           Item  Year      Unit  Value Flag Description
# 166     Whole milk, evaporated  2010    tonnes    0.0    Imputed value
# 167     Whole milk, evaporated  2011    tonnes    0.0    Imputed value
# 168     Whole milk, evaporated  2012    tonnes    0.0    Imputed value
# 169     Whole milk, evaporated  2013    tonnes    0.0    Imputed value
# 170     Whole milk, evaporated  2014    tonnes    0.0    Imputed value
# ...                        ...   ...       ...    ...              ...
# 213674   Whole milk, condensed  2017    tonnes    0.0  Official figure
# 213692  Whole milk, evaporated  2013    tonnes    0.0  Official figure
# 213693  Whole milk, evaporated  2014    tonnes    0.0  Official figure
# 213696  Whole milk, evaporated  2017    tonnes    0.0  Official figure
# 213706  Whole milk, evaporated  2017  1000 US$    0.0  Official figure
#
# [23464 rows x 7 columns]

# %% [markdown]
# # Content Investigation
# ## From looking at the data I am curious about the Flag Description and the data contained under that heading

# %%
# Checks the unique entries for Flag Description.
df['Flag Description'].unique()
# Out:
# array(['Official figure', 'Estimated value', 'Imputed value',
#        'Unofficial figure',
#        'Missing value (data cannot exist, not applicable)',
#        'Figure from international organizations'], dtype=object)

# %%
# Displays data with Missing value (data cannot exist, not applicable) as the flag description
df[df['Flag Description'] =='Missing value (data cannot exist, not applicable)']
# Out:
#                                                    Area     Element  \
# 505                                            Bulgaria  Production
# 506                                            Bulgaria  Production
# 507                                            Bulgaria  Production
# 508                                            Bulgaria  Production
# 547                                            Bulgaria  Production
# ...                                                 ...         ...
# 4144  United Kingdom of Great Britain and Northern I...  Production
# 4145  United Kingdom of Great Britain and Northern I...  Production
# 4146  United Kingdom of Great Britain and Northern I...  Production
# 4147  United Kingdom of Great Britain and Northern I...  Production
# 4148  United Kingdom of Great Britain and Northern I...  Production
#
#                     Item  Year    Unit  Value  \
# 505      Buttermilk, dry  2010  tonnes    NaN
# 506      Buttermilk, dry  2011  tonnes    NaN
# 507      Buttermilk, dry  2012  tonnes    NaN
# 508      Buttermilk, dry  2013  tonnes    NaN
# 547   Ghee from cow milk  2010  tonnes    NaN
# ...                  ...   ...     ...    ...
# 4144             Yoghurt  2014  tonnes    NaN
# 4145             Yoghurt  2015  tonnes    NaN
# 4146             Yoghurt  2016  tonnes    NaN
# 4147             Yoghurt  2017  tonnes    NaN
# 4148             Yoghurt  2018  tonnes    NaN
#
#                                        Flag Description
# 505   Missing value (data cannot exist, not applicable)
# 506   Missing value (data cannot exist, not applicable)
# 507   Missing value (data cannot exist, not applicable)
# 508   Missing value (data cannot exist, not applicable)
# 547   Missing value (data cannot exist, not applicable)
# ...                                                 ...
# 4144  Missing value (data cannot exist, not applicable)
# 4145  Missing value (data cannot exist, not applicable)
# 4146  Missing value (data cannot exist, not applicable)
# 4147  Missing value (data cannot exist, not applicable)
# 4148  Missing value (data cannot exist, not applicable)
#
# [157 rows x 7 columns]

# %% [markdown]
# ## As the volume of rows is higher when the unavailable data is selected rather than a Zero value, I'll remove missing alue rows as countries may have had with production of a product and only generated zero.

# %%
# Removes the rows with Missing Value from the Dataframe
df.drop(df[df['Flag Description'] =='Missing value (data cannot exist, not applicable)'].index, inplace = True);

# %%
# Displays the count of missing or null values in the data
df.isnull().sum()
# Out:
# Area                  0
# Element               0
# Item                  0
# Year                  0
# Unit                  0
# Value               304
# Flag Description      0
# dtype: int64

# %% [markdown]
# ## Looking at the list of Countries in the Dataframe, its time to remove the countires that are not part of the EU e.g. The UK

# %%
# Checks the unique entries for Area.
df['Area'].unique()
# Out:
# array(['Albania', 'Austria', 'Belarus', 'Belgium',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania',
#        'Luxembourg', 'Malta', 'Montenegro', 'Netherlands',
#        'North Macedonia', 'Norway', 'Poland', 'Portugal',
#        'Republic of Moldova', 'Romania', 'Russian Federation', 'Serbia',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Ukraine', 'United Kingdom of Great Britain and Northern Ireland',
#        'Europe', 'Faroe Islands'], dtype=object)

# %% [markdown]
# ## From this list I can see 17 countries that are not part of the EU or EEA so I will remove them and update the data.
#
# ## This data was recorded when the UK was still part of the EU, I want to check if the UK data is still included and if so remove it. I also want to check that all countries recorded are part of the EU/EEC

# %%
# Drops the countries not part of the EU from the Dataframe using the .drop function
df.drop(df[df['Area'].str.contains('Albania|Faroe Islands|Belarus|Belgium-Luxembourg|Bosnia and Herzegovina|Czechia|Czechoslovakia|Montenegro|North Macedonia|Republic of Moldova|Russian Federation|Serbia|Serbia and Montenegro|Switzerland|Ukraine|United Kingdom of Great Britain and Northern Ireland|USSR|Yugoslav SFR|Europe')==True].index, inplace = True)

# %%
# Checks the unique entries for Area to ensure only the EU Members remain.
df['Area'].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Denmark', 'Estonia',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden'], dtype=object)

# %% [markdown]
# ## While I have opted to remove Europe from the Country Fields, this is to factor in the likes of the UK being part of the EU for some of the years in the data. I will create a new column called "Origin" to hold the grouped data for the current EU member countries as "Europe" and Ireland as two new variables.

# %%
# This is to create a column where based on the country it will be populated with either Ireland or Europe
df['Origin'] = np.where(df['Area'] == 'Ireland', 'Ireland', 'Europe')

# %% [markdown]
# ## Checking to see if the value of the rows has decreased by the correct amount and it has

# %%
# Displays the number or rows and columns in the dataset
df.shape
# Out:
# (174138, 8)

# %%
# Displays the top 5 rows of the dataframe
df.head()
# Out:
#        Area     Element                Item  Year    Unit    Value  \
# 50  Austria  Production  Butter of cow milk  2010  tonnes  33792.0
# 51  Austria  Production  Butter of cow milk  2011  tonnes  34975.0
# 52  Austria  Production  Butter of cow milk  2012  tonnes  35607.0
# 53  Austria  Production  Butter of cow milk  2013  tonnes  34686.0
# 54  Austria  Production  Butter of cow milk  2014  tonnes  34165.0
#
#    Flag Description  Origin
# 50  Official figure  Europe
# 51  Official figure  Europe
# 52  Official figure  Europe
# 53  Official figure  Europe
# 54  Official figure  Europe

# %%
# I can see the index is out of step so I will reset that, remove the new index that will appear and display the top 5 rows to check everything worked
df = df.reset_index()
df.drop(['index'], axis=1, inplace=True)
df.head()
# Out:
#       Area     Element                Item  Year    Unit    Value  \
# 0  Austria  Production  Butter of cow milk  2010  tonnes  33792.0
# 1  Austria  Production  Butter of cow milk  2011  tonnes  34975.0
# 2  Austria  Production  Butter of cow milk  2012  tonnes  35607.0
# 3  Austria  Production  Butter of cow milk  2013  tonnes  34686.0
# 4  Austria  Production  Butter of cow milk  2014  tonnes  34165.0
#
#   Flag Description  Origin
# 0  Official figure  Europe
# 1  Official figure  Europe
# 2  Official figure  Europe
# 3  Official figure  Europe
# 4  Official figure  Europe

# %%
# Displays the count of duplicate values in the dataframe
df.duplicated().sum();

# %%
# Displays the list of duplicate values in the dataframe
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 174133     True
# 174134    False
# 174135     True
# 174136    False
# 174137     True
# Length: 174138, dtype: bool

# %%
# Displays the last 10 entries in the dataframe
df.tail(10)
# Out:
#           Area          Element                   Item  Year      Unit  Value  \
# 174128  Sweden  Export Quantity  Whole milk, condensed  2015    tonnes    0.0
# 174129  Sweden  Export Quantity  Whole milk, condensed  2016    tonnes    0.0
# 174130  Sweden  Export Quantity  Whole milk, condensed  2017    tonnes    0.0
# 174131  Sweden  Export Quantity  Whole milk, condensed  2018    tonnes    0.0
# 174132  Sweden  Export Quantity  Whole milk, condensed  2019    tonnes    0.0
# 174133  Sweden     Export Value  Whole milk, condensed  2015  1000 US$    0.0
# 174134  Sweden     Export Value  Whole milk, condensed  2016  1000 US$    0.0
# 174135  Sweden     Export Value  Whole milk, condensed  2017  1000 US$    0.0
# 174136  Sweden     Export Value  Whole milk, condensed  2018  1000 US$    0.0
# 174137  Sweden     Export Value  Whole milk, condensed  2019  1000 US$    0.0
#
#        Flag Description  Origin
# 174128  Official figure  Europe
# 174129  Official figure  Europe
# 174130  Official figure  Europe
# 174131  Official figure  Europe
# 174132  Official figure  Europe
# 174133  Official figure  Europe
# 174134  Official figure  Europe
# 174135  Official figure  Europe
# 174136  Official figure  Europe
# 174137  Official figure  Europe

# %%
# Displays the number of unique values in the dataset
df.nunique()
# Out:
# Area                   27
# Element                 5
# Item                   26
# Year                   10
# Unit                    2
# Value               21599
# Flag Description        4
# Origin                  2
# dtype: int64

# %% [markdown]
# ## Another consideration with the 2 tables is
# ## - The different product types.
# ## I will need to correct products so they are consistent through the dataframes and to bring the tables in line and comparable.

# %%
# Displays the number of unique values for Item in the dataset
df['Item'].unique()
# Out:
# array(['Butter of cow milk',
#        'Cheese from milk of goats, fresh or processed',
#        'Cheese from milk of sheep, fresh or processed',
#        'Cheese from skimmed cow milk', 'Cheese from whole cow milk',
#        'Cream, fresh', 'Pig fat, rendered', 'Skim milk and whey powder',
#        'Skim milk of cows', 'Tallow', 'Whey, condensed', 'Whey, dry',
#        'Whole milk powder', 'Whole milk, condensed',
#        'Whole milk, evaporated', 'Skim milk, condensed',
#        'Buttermilk, dry', 'Raw silk (not thrown)',
#        'Skim milk, evaporated', 'Yoghurt',
#        'Cheese from milk of buffalo, fresh or processed',
#        'Butter of goat milk', 'Buttermilk, curdled and acidified milk',
#        'Dairy products n.e.c.', 'Fat of pigs', 'Raw milk of cattle'],
#       dtype=object)

# %%
# This will drop the listed Item entries fromt he dataframe and display the column and row volumes
df.drop(df[df['Item'].str.contains('Skim milk of cows|Buttermilk, curdled and acidified milk|Whey, condensed|Skim milk, evaporated|Dairy products n.e.c.|Butter of goat milk|Fat of pigs|Skim milk, condensed|Yoghurt|Tallow|Raw milk of cattle|Whey, dry|Raw silk (not thrown)|Cheese from skimmed cow milk|Cheese from milk of buffalo, fresh or processed|Buttermilk, dry|Cheese from milk of goats, fresh or processed|Pig fat, rendered')==True].index, inplace = True);
df.drop(df[df['Item'] =='Raw silk (not thrown)'].index, inplace = True);
df.drop(df[df['Item'] =='Ghee from cow milk'].index, inplace = True);
df.shape
# Out:
# /var/folders/4z/t6d1mv855tg3_0k261zlc6z00000gr/T/ipykernel_28773/835939743.py:2: UserWarning:
#
# This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# (94418, 8)

# %%
# Displays the number of unique values for Item in the dataset
df['Item'].unique()
# Out:
# array(['Butter of cow milk',
#        'Cheese from milk of sheep, fresh or processed',
#        'Cheese from whole cow milk', 'Cream, fresh',
#        'Skim milk and whey powder', 'Whole milk powder',
#        'Whole milk, condensed', 'Whole milk, evaporated'], dtype=object)

# %%
# Displays the number of null values in the dataset
df.isnull().sum()
# Out:
# Area                 0
# Element              0
# Item                 0
# Year                 0
# Unit                 0
# Value               24
# Flag Description     0
# Origin               0
# dtype: int64

# %% [markdown]
# ## As the volume of Null values is so small incomparison to the overall size of the Dataframe, I am going to drop them out.

# %%
# Drops any rows with Null, NA or NaN values 
df.dropna()
# Out:
#            Area       Element                   Item  Year      Unit    Value  \
# 0       Austria    Production     Butter of cow milk  2010    tonnes  33792.0
# 1       Austria    Production     Butter of cow milk  2011    tonnes  34975.0
# 2       Austria    Production     Butter of cow milk  2012    tonnes  35607.0
# 3       Austria    Production     Butter of cow milk  2013    tonnes  34686.0
# 4       Austria    Production     Butter of cow milk  2014    tonnes  34165.0
# ...         ...           ...                    ...   ...       ...      ...
# 174133   Sweden  Export Value  Whole milk, condensed  2015  1000 US$      0.0
# 174134   Sweden  Export Value  Whole milk, condensed  2016  1000 US$      0.0
# 174135   Sweden  Export Value  Whole milk, condensed  2017  1000 US$      0.0
# 174136   Sweden  Export Value  Whole milk, condensed  2018  1000 US$      0.0
# 174137   Sweden  Export Value  Whole milk, condensed  2019  1000 US$      0.0
#
#        Flag Description  Origin
# 0       Official figure  Europe
# 1       Official figure  Europe
# 2       Official figure  Europe
# 3       Official figure  Europe
# 4       Official figure  Europe
# ...                 ...     ...
# 174133  Official figure  Europe
# 174134  Official figure  Europe
# 174135  Official figure  Europe
# 174136  Official figure  Europe
# 174137  Official figure  Europe
#
# [94394 rows x 8 columns]

# %%
# Displays descriptive statistics about the data.
df.describe()
# Out:
#                Year         Value
# count  94418.000000  9.439400e+04
# mean    2014.602396  7.321674e+03
# std        2.878154  4.658933e+04
# min     2010.000000  0.000000e+00
# 25%     2012.000000  1.200000e+01
# 50%     2015.000000  1.670000e+02
# 75%     2017.000000  1.522000e+03
# max     2019.000000  1.778365e+06

# %%
# Displays the number of unique values for Element in the dataset
df['Element'].unique()
# Out:
# array(['Production', 'Import Quantity', 'Import Value', 'Export Quantity',
#        'Export Value'], dtype=object)

# %%
# Here I have used to pivot to the differences in the Element type, Product is considerable larger that other values in the dataframe

dft = pd.pivot_table(df, index=['Element'], columns=['Item'])
dft
# Out:
#                              Value  \
# Item            Butter of cow milk
# Element
# Export Quantity        1715.108230
# Export Value           7884.467849
# Import Quantity        1861.040378
# Import Value           8544.313860
# Production            71368.465587
#
#                                                                \
# Item            Cheese from milk of sheep, fresh or processed
# Element
# Export Quantity                                     95.784522
# Export Value                                       660.866464
# Import Quantity                                    238.608838
# Import Value                                      1606.360065
# Production                                       26657.092593
#
#                                                           \
# Item            Cheese from whole cow milk  Cream, fresh
# Element
# Export Quantity                5878.575804   2854.711396
# Export Value                  27509.094541   5534.210384
# Import Quantity                5756.479040   2935.696981
# Import Value                  26747.624047   6262.184180
# Production                   288216.182979  93310.379147
#
#                                                              \
# Item            Skim milk and whey powder Whole milk powder
# Element
# Export Quantity               1558.381505        742.695550
# Export Value                  4009.773756       2410.153563
# Import Quantity               1547.035836        819.877104
# Import Value                  3860.662116       2655.155556
# Production                   59476.466667      35024.037433
#
#                                                               \
# Item            Whole milk, condensed Whole milk, evaporated
# Element
# Export Quantity            389.187764            2297.650410
# Export Value               886.664557            2657.718976
# Import Quantity            560.062473            2450.670577
# Import Value              1253.109005            2659.375367
# Production                9446.442029           45517.903955
#
#                               Year  \
# Item            Butter of cow milk
# Element
# Export Quantity        2014.649828
# Export Value           2014.649828
# Import Quantity        2014.706472
# Import Value           2014.706472
# Production             2014.279352
#
#                                                                \
# Item            Cheese from milk of sheep, fresh or processed
# Element
# Export Quantity                                   2012.839150
# Export Value                                      2012.839150
# Import Quantity                                   2012.986907
# Import Value                                      2012.986907
# Production                                        2013.685185
#
#                                                          \
# Item            Cheese from whole cow milk Cream, fresh
# Element
# Export Quantity                2014.659195  2014.579906
# Export Value                   2014.659195  2014.579906
# Import Quantity                2014.646980  2014.674054
# Import Value                   2014.646980  2014.674054
# Production                     2014.238298  2013.758294
#
#                                                              \
# Item            Skim milk and whey powder Whole milk powder
# Element
# Export Quantity               2014.637726       2014.542809
# Export Value                  2014.637726       2014.542809
# Import Quantity               2014.641923       2014.642208
# Import Value                  2014.641923       2014.642208
# Production                    2013.779487       2013.791444
#
#
# Item            Whole milk, condensed Whole milk, evaporated
# Element
# Export Quantity           2014.758650            2014.661033
# Export Value              2014.758650            2014.661033
# Import Quantity           2014.844894            2014.709189
# Import Value              2014.844894            2014.709189
# Production                2013.572464            2013.740113

# %% [markdown]
# ## Now I can see there is a clear difference in the volumes for the different Element type, i am going to dive deeper into the product and country to see if any other points appear.

# %%
# Creates a boxplot to show an Element based on Item and Value
df_prod = df.loc[(df['Element'] == 'Production')]
df_prod.boxplot(column =['Value'], by = ['Item'], figsize =(20,12))

plt.suptitle("Box plot for Items in Production Element", fontsize=20, color="Black", x=0.51, y=0.95)
plt.xlabel("Item", fontsize=16)

plt.show()

# %%
# Creates a boxplot to show an Element based on Item and Value
df_expq = df.loc[(df['Element'] == 'Export Quantity')]
df_expq.boxplot(column =['Value'], by = ['Item'], figsize =(20,12))

plt.suptitle("Box plot for Items in Export Quantity", fontsize=20, color="black", x=0.51, y=0.95)
plt.xlabel("Item", fontsize=16)

plt.show()

# %%
# Creates a boxplot to show an Element based on Item and Value
df_impq = df.loc[(df['Element'] == 'Import Quantity')]
df_impq.boxplot(column =['Value'], by = ['Item'], figsize =(20,12))

plt.suptitle("Box plot for Items in Import Quantity", fontsize=20, color="black", x=0.51, y=0.95)
plt.xlabel("Item", fontsize=16)

plt.show()

# %%
# Creates a boxplot to show an Element based on Item and Value
df_expval = df.loc[(df['Element'] == 'Export Value')]
df_expval.boxplot(column =['Value'], by = ['Item'], figsize =(20,12))

plt.suptitle("Box plot for Items in Export Value", fontsize=20, color="black", x=0.51, y=0.95)
plt.xlabel("Item", fontsize=16)

plt.show()

# %%
# Creates a boxplot to show an Element based on Item and Value
df_impval = df.loc[(df['Element'] == 'Import Value')]
df_impval.boxplot(column =['Value'], by = ['Item'], figsize =(20,12))

plt.suptitle("Box plot for Items in Import Value", fontsize=20, color="black", x=0.51, y=0.95)
plt.xlabel("Item", fontsize=16)

plt.show()

# %%
# This set of Plots is to show the trends of Items by Area
pd.pivot_table(df.reset_index(),
               index='Area', columns='Item', values='Value'
              ).plot(subplots=True, layout=(4,2), figsize =(20,12), title=('Trends of Items by Area'))
# Out:
# array([[<AxesSubplot:xlabel='Area'>, <AxesSubplot:xlabel='Area'>],
#        [<AxesSubplot:xlabel='Area'>, <AxesSubplot:xlabel='Area'>],
#        [<AxesSubplot:xlabel='Area'>, <AxesSubplot:xlabel='Area'>],
#        [<AxesSubplot:xlabel='Area'>, <AxesSubplot:xlabel='Area'>]],
#       dtype=object)

# %% [markdown]
# ## Now the data has been cleaned as the Dataframe and I can see how the variables differ based on the different Elements, its time to split the data into  two dataframes -
# ## One in Production and Quanitity type records when the value is in tonnes

# %%
# Group the data into groups 
grouped = df.groupby(['Unit', 'Element'])

# Defines a function to select the groups where the 'Feature' column equals 'tonnes'
def select_tonnes(group):
    if group['Unit'].iloc[0] == 'tonnes':
        return group

# Apply the function to each group
product = grouped.apply(select_tonnes)

# Drop the groups that were not selected
product = product.dropna()

# Reset the index of the resulting DataFrame
product = product.reset_index(drop=True)

# Print the resulting DataFrame
product.head()
# Out:
#       Area          Element                Item  Year    Unit  Value  \
# 0  Austria  Export Quantity  Butter of cow milk  2012  tonnes    0.0
# 1  Austria  Export Quantity  Butter of cow milk  2013  tonnes    0.0
# 2  Austria  Export Quantity  Butter of cow milk  2014  tonnes    0.0
# 3  Austria  Export Quantity  Butter of cow milk  2015  tonnes    0.0
# 4  Austria  Export Quantity  Butter of cow milk  2016  tonnes   32.0
#
#   Flag Description  Origin
# 0  Official figure  Europe
# 1  Official figure  Europe
# 2  Official figure  Europe
# 3  Official figure  Europe
# 4  Official figure  Europe

# %% [markdown]
# ## Second by Export and Import Value in Dollars.

# %%
# Group the data into groups
grouped = df.groupby(['Unit', 'Element'])

# Define a function to select the groups where the 'Feature' column equals '1000 US$'
def select_dollar(group):
    if group['Unit'].iloc[0] == '1000 US$':
        return group

# Apply the function to each group
transaction = grouped.apply(select_dollar)

# Drop the groups that were not selected
transaction = transaction.dropna()

# Reset the index of the resulting DataFrame
transaction = transaction.reset_index(drop=True)

# Print the resulting DataFrame
transaction.head()
# Out:
#       Area       Element                Item  Year      Unit  Value  \
# 0  Austria  Export Value  Butter of cow milk  2012  1000 US$    1.0
# 1  Austria  Export Value  Butter of cow milk  2013  1000 US$    0.0
# 2  Austria  Export Value  Butter of cow milk  2014  1000 US$    0.0
# 3  Austria  Export Value  Butter of cow milk  2015  1000 US$    0.0
# 4  Austria  Export Value  Butter of cow milk  2016  1000 US$  190.0
#
#   Flag Description  Origin
# 0  Official figure  Europe
# 1  Official figure  Europe
# 2  Official figure  Europe
# 3  Official figure  Europe
# 4  Official figure  Europe

# %%
# Saving the Dataframes into CSV files
transaction.to_csv('transaction.csv', index=False)
product.to_csv('product.csv', index=False)

# %%
# Here I used the describe function to see how the new column displayed Ireland versus Europe in import and export transactions
transaction.groupby('Origin')['Value'].describe()
# Out:
#            count         mean           std  min    25%    50%     75%  \
# Origin
# Europe   45240.0  9470.950796  50855.141354  0.0  23.00  281.0  2378.5
# Ireland   1208.0  7591.278146  25472.524581  0.0  69.75  432.5  3037.5
#
#                max
# Origin
# Europe   1472600.0
# Ireland   376678.0

# %%
# Here I group the data by Area and value then sort by the mean column to identify Ireland position on the list.
group_trans = transaction.groupby('Area')['Value'].describe()

result_trans = group_trans.sort_values('mean', ascending=False)

result_trans
# Out:
#               count          mean            std  min     25%     50%  \
# Area
# Germany      3196.0  32350.549750  114125.378679  0.0  253.75  2244.0
# France       2764.0  21447.414255   76317.982668  0.0   73.00   894.5
# Netherlands  3038.0  20349.996708   87599.949733  0.0   58.25   717.0
# Italy        2729.0  16045.737633   75512.965332  0.0   20.00   319.0
# Belgium      2678.0  15485.154220   50952.115401  0.0   91.00   735.5
# Spain        2077.0   8975.558498   32082.256760  0.0   31.00   362.0
# Ireland      1208.0   7591.278146   25472.524581  0.0   69.75   432.5
# Denmark      2245.0   7155.310913   30604.298136  0.0    4.00   178.0
# Luxembourg   1093.0   5977.631290   27969.753716  0.0   12.00   167.0
# Greece       1811.0   5862.722253   19674.700093  0.0   28.00   320.0
# Poland       2682.0   5692.494780   15002.928522  0.0   54.25   563.0
# Sweden       1666.0   5279.806122   20810.419774  0.0   24.00   305.0
# Austria      2295.0   4876.420915   27432.046934  0.0   14.00   146.0
# Finland      1121.0   4221.363069   13489.863196  0.0   20.00   223.0
# Portugal     1490.0   2676.072483    7689.498247  0.0   13.00   127.5
# Slovakia     1488.0   2586.940188    7960.115117  0.0   28.75   179.5
# Lithuania    1718.0   2286.008731    9241.607812  0.0   31.00   245.0
# Hungary      1581.0   1805.862745    7712.101938  0.0   10.00   170.0
# Bulgaria     1370.0   1776.218248    4564.759894  0.0   30.00   219.0
# Romania      1899.0   1533.378620    6957.911159  0.0    5.00    91.0
# Norway        808.0   1415.766089    5432.324636  0.0    3.00    46.5
# Latvia       1258.0   1389.121622    3628.412721  0.0    8.25   134.0
# Croatia       968.0   1175.560950    4389.470753  0.0   10.00    74.5
# Slovenia     1164.0   1073.241409    3798.741738  0.0    6.00    66.0
# Estonia      1213.0   1045.099753    2779.642956  0.0   12.00   112.0
# Malta         571.0    534.812609    1369.125379  0.0   15.00   117.0
# Iceland       317.0    162.321767     485.866716  0.0    0.00     3.0
#
#                   75%        max
# Area
# Germany      17218.75  1472600.0
# France        9277.50   933176.0
# Netherlands   7613.50  1373270.0
# Italy         4260.00  1155970.0
# Belgium       5633.75   524916.0
# Spain         3533.00   302750.0
# Ireland       3037.50   376678.0
# Denmark       2046.00   385370.0
# Luxembourg    1571.00   313361.0
# Greece        2787.00   179433.0
# Poland        3371.50   159392.0
# Sweden        2100.00   254841.0
# Austria       1031.00   337662.0
# Finland       1883.00   121869.0
# Portugal      1326.00    90362.0
# Slovakia      1048.00    86015.0
# Lithuania     1064.25   114077.0
# Hungary        961.00   115913.0
# Bulgaria      1199.50    45159.0
# Romania        740.00   136459.0
# Norway         356.00    54169.0
# Latvia         969.75    50381.0
# Croatia        631.00    54470.0
# Slovenia       405.75    37920.0
# Estonia        809.00    29976.0
# Malta          416.50    11222.0
# Iceland         54.00     4234.0

# %%
ax_trans = sns.countplot(x='Origin', hue='Item', data=transaction)

plt.suptitle("Origin split based on Item", fontsize=16, color="black", x=0.51, y=1.01)
plt.xlabel("Item", fontsize=12)
sns.move_legend(ax_trans, "upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### Here I am going to repeat the analysis I did with the transaction dataset on the production Dataset

# %%
# Here I used the describe function to see how the new column displayed Ireland versus Europe terms of production volume
pro_element = product.loc[(product['Element'] == 'Production')]

pro_element.groupby('Origin')['Value'].describe()
# Out:
#           count          mean            std  min     25%      50%        75%  \
# Origin
# Europe   1436.0  90500.442201  218908.533354  0.0  2901.5  18553.5   70201.25
# Ireland    62.0  88311.596774   86614.870817  0.0  5700.0  54735.0  162802.50
#
#                max
# Origin
# Europe   1778365.0
# Ireland   278400.0

# %%
# Here I group the data by Area and value then sort by the mean column to identify Ireland position on the list.
group_prod = pro_element.groupby('Area')['Value'].describe()

result_prod = group_prod.sort_values('mean', ascending=False)

result_prod
# Out:
#              count           mean            std      min        25%  \
# Area
# Germany       58.0  469431.396552  420726.314511  33000.0  129700.00
# France        66.0  389277.000000  501294.756547   9558.0   66213.00
# Netherlands   52.0  289253.576923  290563.117098  50000.0   72749.75
# Italy         52.0  267754.211538  432187.370207      0.0    4759.00
# Poland        64.0  172212.203125  227459.188532      0.0    1515.50
# Denmark       58.0  109561.724138  127685.328349   1000.0   39675.00
# Ireland       62.0   88311.596774   86614.870817      0.0    5700.00
# Belgium       62.0   87675.532258   58222.048063  20460.0   47302.50
# Spain         70.0   64584.328571   56876.435335  13399.0   16904.75
# Finland       44.0   50971.000000   30664.569287   3606.0   21586.25
# Sweden        63.0   50101.428571   37155.807643      0.0   28890.00
# Austria       68.0   42664.573529   63213.565663      0.0    1494.25
# Greece        33.0   41717.757576   53660.231715   1000.0    1994.00
# Lithuania     59.0   26790.796610   23529.542532    760.0    7850.00
# Hungary       59.0   24420.237288   32404.865436     94.0    1276.50
# Norway        70.0   22265.400000   24806.203095    695.0    2405.25
# Romania       56.0   20963.714286   26323.560904    610.0    1900.00
# Portugal      75.0   19748.426667   17822.117920   1000.0    7819.50
# Bulgaria      51.0   14987.000000   27244.198618      0.0       0.00
# Latvia        59.0   13155.135593   15245.714820    280.0    2529.00
# Slovakia      64.0   10476.890625   13844.446422    521.0    1818.00
# Estonia       56.0    9341.232143   13449.804912      0.0    1520.00
# Luxembourg    24.0    8673.250000    9045.704463    184.0     619.00
# Croatia       50.0    6845.840000   12100.673517      0.0     257.75
# Slovenia      60.0    6049.083333    7507.251882      0.0       0.00
# Iceland       55.0    3292.054545    4128.138875      0.0     354.50
# Malta          8.0     160.250000       4.464143    150.0     161.00
#
#                   50%        75%        max
# Area
# Germany      392018.5  545750.00  1484200.0
# France       250000.0  388716.50  1778365.0
# Netherlands  138092.0  371305.25   953000.0
# Italy         94045.0  121000.00  1203760.0
# Poland        89540.5  202096.25   744000.0
# Denmark       60050.0   89400.00   457400.0
# Ireland       54735.0  162802.50   278400.0
# Belgium       70874.0  111967.50   246440.0
# Spain         42095.0  103383.00   205716.0
# Finland       51290.0   67258.75   108897.0
# Sweden        40000.0   87660.00   112700.0
# Austria        9710.0   64130.00   204798.0
# Greece         4200.0   46000.00   139488.0
# Lithuania     16202.0   44374.50    80300.0
# Hungary        5250.0   61250.00    87018.0
# Norway        14550.0   35791.00    80166.0
# Romania       10673.0   24569.75    94677.0
# Portugal      11915.0   26459.00    65395.0
# Bulgaria       1056.0    9139.50    89780.0
# Latvia         5069.0   31050.00    47420.0
# Slovakia       4730.0   11250.00    46838.0
# Estonia        4650.0    8012.25    45500.0
# Luxembourg     5181.0   18712.50    22800.0
# Croatia         651.0    4777.00    35670.0
# Slovenia       2654.0   14324.00    22742.0
# Iceland        2000.0    3140.00    13552.0
# Malta           162.0     162.00      164.0

# %%
# This graph is to show the Origin split based on the source element
ax_prod = sns.countplot(x='Origin', hue='Element', data=product)

plt.suptitle("Origin split based on Element", fontsize=16, color="black", x=0.51, y=1.01)
plt.xlabel("Item", fontsize=12)
sns.move_legend(ax_prod, "upper left", bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ## Now we have a clear understanding of the data, its features, structure and completed descriptive statistics on it. I am going to begin feature engineering and start with removing the outliers.

# %%
# This box plots shows the boxplot for the transaction dataframe, there is clear evidence of significant outliers in the data

plt.figure(figsize=(8, 4), dpi=120)

sns.boxplot(data=transaction, x='Value', hue='Element')

plt.suptitle("Outliers included", fontsize=18, color="black", x=0.51, y=1.01)
plt.xlabel("Value in Dollars", fontsize=12)
plt.xticks(fontsize=12)

plt.show()

# %%
# This code block will create the quantile ranges and create the IQR function to help with removing the outliers later
Q1 = transaction.loc[transaction['Origin'] == 'Europe'].quantile(0.25)
Q3 = transaction.loc[transaction['Origin'] == 'Europe'].quantile(0.75)

IQR = Q3 - Q1
print(IQR)
# Out:
# Year        5.0
# Value    2355.5
# dtype: float64

# %%
# This completed the outlier removal and present the shape of the changed data
transaction = transaction[~((transaction < (Q1-1.5 * IQR)) |(transaction > (Q3 + 1.5 * IQR))).any(axis=1)]
transaction.shape
# Out:
# /var/folders/4z/t6d1mv855tg3_0k261zlc6z00000gr/T/ipykernel_28773/3443205546.py:2: FutureWarning:
#
# Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# (38851, 8)

# %%
# This box plots shows the boxplot for the updated transaction dataframe, 

sns.boxplot(data=transaction, x='Value', color="#2b7bba")

plt.suptitle("Outliers Removed", fontsize=18, color="black", x=0.51, y=1.01)
plt.xlabel("Value", fontsize=12)
plt.xticks(fontsize=12)

plt.show()

# %%
# This code will create the corelation function and plot the heatmap for the new transaction data
# This is good to see if there is any correlation between my numerical data and based on the result, its negatively correlated
corelation = transaction.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

plt.suptitle("Transaction Data Heatmap", fontsize=18, color="black")

plt.show()

# %%
# I am using Pairplot here to further identify any additonal correlations in the data for Ireland

ax_ptrans = sns.pairplot(transaction.loc[transaction['Origin'] == 'Ireland'], hue='Element')

plt.suptitle("Transaction data Pairplot for Ireland", fontsize=16, color="black", x=0.51, y=1.05)

plt.show()

# %%
# I am using Pairplot here to further identify any additonal correlations in the data for Europe

ax_ptrans = sns.pairplot(transaction.loc[transaction['Origin'] == 'Europe'], hue='Element')

plt.suptitle("Transaction data Pairplot for Europe", fontsize=16, color="black", x=0.51, y=1.01)

plt.show()

# %%
# This box plots shows the boxplot for the product dataframe, there is clear evidence of significant outliers in the data

plt.figure(figsize=(8, 4), dpi=120)

sns.boxplot(data=product, x='Value', color="#2b7bba")

plt.suptitle("Outliers Included", fontsize=18, color="black", x=0.51, y=1.01)
plt.xlabel("Value", fontsize=12)
plt.xticks(fontsize=12)

plt.show()

# %%
# This code block will create the quantile ranges and create the IQR function to help with removing the outliers later
Q1 = product.loc[product['Origin'] == 'Europe'].quantile(0.25)
Q3 = product.loc[product['Origin'] == 'Europe'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year       5.0
# Value    879.0
# dtype: float64

# %%
# This completed the outlier removal and present the shape of the changed data

product = product[~((product < (Q1-1.5 * IQR)) |(product > (Q3 + 1.5 * IQR))).any(axis=1)]
product.shape
# Out:
# /var/folders/4z/t6d1mv855tg3_0k261zlc6z00000gr/T/ipykernel_28773/1052711605.py:3: FutureWarning:
#
# Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# (39829, 8)

# %%
# This box plots shows the boxplot for the updated product dataframe, 

plt.figure(figsize=(8, 4), dpi=120)

sns.boxplot(data=product, x='Value', color="#2b7bba")

plt.suptitle("Outliers removed", fontsize=18, color="black", x=0.51, y=1.01)
plt.xlabel("Value in Tonnes", fontsize=12)
plt.xticks(fontsize=12)

plt.show()

# %%
# This code will create the corelation function and plot the heatmap for the new transaction data
# This is good to see if there is any correlation between my numerical data and based on the result, its negatively correlated

corelation = product.corr()

sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

plt.suptitle("Product Data Heatmap", fontsize=18, color="black")

plt.show()

# %%
# I am using Pairplot here to further identify any additonal correlations in the data for Europe

ax_pprod = sns.pairplot(product.loc[product['Origin'] == 'Europe'], hue='Element')

plt.suptitle("Product data Pairplot for Europe", fontsize=16, color="black", x=0.51, y=1.01)

plt.show()

# %%
# I am using Pairplot here to further identify any additonal correlations in the data for Ireland

ax_pprod = sns.pairplot(product.loc[product['Origin'] == 'Ireland'], hue='Element')

plt.suptitle("Product data Pairplot for Ireland", fontsize=16, color="black", x=0.51, y=1.01)

plt.show()

# %% [markdown]
# ## Now we completed the EDA on the data, I am going to visualise data in a Choropleth and create a Dashboard to display the data so far.

# %%
----euro_countries = json.load(open("geo.json", "r"))
# Out:
#   Input In [92]
#     ----euro_countries = json.load(open("geo.json", "r"))
#     ^
# SyntaxError: cannot assign to operator

# %%
euro_countries['features'][1]['properties']

# %%
country_id_map = {}
for feature in euro_countries["features"]:
    feature["id"] = feature["properties"]["su_a3"]
    country_id_map[feature["properties"]["name"]] = feature["id"]

# %%
transaction["id"] = transaction["Area"].apply(lambda x: country_id_map[x])
transaction.head()

# %%
product["id"] = product["Area"].apply(lambda x: country_id_map[x])
product.head()

# %%
import plotly.graph_objects as go

# %%
total = transaction['Value'].sum()


fig = px.choropleth_mapbox(
    transaction,
    locations="id",
    geojson=euro_countries,
    color="Element",
    color_continuous_midpoint=total,
    hover_name="Area",
    hover_data=["Value"],
    title="Highest Value Product by Combined Import & Export Value",
    mapbox_style="carto-positron",
    center={"lat": 52, "lon": 16},
    zoom=3,
    opacity=0.5,
)
fig.update_geos(fitbounds="locations", visible=False)

#fig.show()

# %%
total2 = product['Value'].sum()


fig = px.choropleth_mapbox(
    product,
    locations="id",
    geojson=euro_countries,
    color="Item",
    color_continuous_midpoint=total,
    hover_name="Area",
    hover_data=["Value"],
    title="Highest Value Product by Average Tonnes",
    mapbox_style="carto-positron",
    center={"lat": 52, "lon": 16},
    zoom=3,
    opacity=0.5,
)
fig.update_geos(fitbounds="locations", visible=False)

fig.show()

# %%
idf = transaction.interactive()

# Define Panel widgets
years = pn.widgets.IntSlider(name='Years', start=2010, end=2019, step=1)
countries = pn.widgets.ToggleGroup(
    name='Countries',
    options=['Europe', 'Ireland'], 
    value=['Europe', 'Ireland'],
    button_type='success')
flag = pn.widgets.ToggleGroup(
    name='Value Source',
    options=['Export Value', 'Import Value'], 
    value=['Export Value', 'Import Value'],
    button_type='success')
yaxis = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Value', 'Year'],
    button_type='success'
)

# Combine pipeline and widgets
ipipeline = (
    idf[
        (idf.Year == years) & 
        (idf.Country.isin(countries)) & 
        (idf.Element.isin(flag))
    ]
    .groupby(['Country', 'Item'])[yaxis].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Item')  
    .reset_index(drop=True)
)

# Pipe to hvplot
ihvplot = ipipeline.hvplot(x='Item', y=yaxis, by='Country', color=["#f29559", "#b8b08d", "#283845"], line_width=6, height=400)

# Layout using Template
template = pn.template.FastListTemplate(
    title='Import & Export values for Ireland & Europe', 
    sidebar=[years, 'Country', countries, 'Value Source', flag],
    main=[ihvplot.panel()],
    accent_base_color="#f2d492",
    header_background="#202c39",
)
template.show()

# %%
itable = ipipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size=10, sizing_mode='stretch_width')
itable

# %%
product['Element'].unique()

# %%
idf2 = product.interactive()

# Define Panel widgets
years = pn.widgets.IntSlider(name='Years', start=2010, end=2019, step=1)
countries = pn.widgets.ToggleGroup(
    name='Countries',
    options=['Europe', 'Ireland'], 
    value=['Europe', 'Ireland'],
    button_type='success')
flag = pn.widgets.ToggleGroup(
    name='Value Source',
    options=['Export Quantity', 'Import Quantity', 'Production'], 
    value=['Export Quantity', 'Import Quantity', 'Production'],
    button_type='success')
yaxis = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Value', 'Year'],
    button_type='success'
)

# Combine pipeline and widgets
ipipeline2 = (
    idf2[
        (idf2.Year == years) & 
        (idf2.Country.isin(countries)) & 
        (idf2.Element.isin(flag))
    ]
    .groupby(['Country', 'Item'])[yaxis].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='Item')  
    .reset_index(drop=True)
)

# Pipe to hvplot
ihvplot = ipipeline2.hvplot(x='Item', y=yaxis, by='Country', color=["#f29559", "#b8b08d", "#283845"], line_width=6, height=400)

# Layout using Template
template2 = pn.template.FastListTemplate(
    title='Import & Export values for Ireland & Europe', 
    sidebar=[years, 'Country', countries, 'Value Source', flag],
    main=[ihvplot.panel()],
    accent_base_color="#f2d492",
    header_background="#202c39",
)
template2.show()

# %%
# Here I have used to pivot to the differences in the Element type, Product is considerable larger that other values in the dataframe

dft1 = pd.pivot_table(df, index=['Year', 'Area', 'Item'], columns=['Element'])
dft1
# Out:
#                                                                      Value  \
# Element                                                    Export Quantity
# Year Area    Item
# 2010 Austria Butter of cow milk                                 120.500000
#              Cheese from milk of sheep, fresh or processed        4.111111
#              Cheese from whole cow milk                        2660.615385
#              Cream, fresh                                      1001.266667
#              Skim milk and whey powder                          148.937500
# ...                                                                    ...
# 2019 Sweden  Cream, fresh                                        18.000000
#              Skim milk and whey powder                         1127.666667
#              Whole milk powder                                  151.538462
#              Whole milk, condensed                                0.200000
#              Whole milk, evaporated                            1722.285714
#
#                                                                           \
# Element                                                     Export Value
# Year Area    Item
# 2010 Austria Butter of cow milk                               677.333333
#              Cheese from milk of sheep, fresh or processed     23.000000
#              Cheese from whole cow milk                     14460.230769
#              Cream, fresh                                    1616.200000
#              Skim milk and whey powder                        455.062500
# ...                                                                  ...
# 2019 Sweden  Cream, fresh                                      35.750000
#              Skim milk and whey powder                       2441.875000
#              Whole milk powder                                591.692308
#              Whole milk, condensed                              1.200000
#              Whole milk, evaporated                          1204.571429
#
#                                                                             \
# Element                                                    Import Quantity
# Year Area    Item
# 2010 Austria Butter of cow milk                                1106.692308
#              Cheese from milk of sheep, fresh or processed      126.666667
#              Cheese from whole cow milk                        3414.913043
#              Cream, fresh                                      1040.888889
#              Skim milk and whey powder                         1627.000000
# ...                                                                    ...
# 2019 Sweden  Cream, fresh                                      2072.600000
#              Skim milk and whey powder                          639.833333
#              Whole milk powder                                  460.555556
#              Whole milk, condensed                              221.571429
#              Whole milk, evaporated                             401.142857
#
#                                                                           \
# Element                                                     Import Value
# Year Area    Item
# 2010 Austria Butter of cow milk                              5386.846154
#              Cheese from milk of sheep, fresh or processed   1002.833333
#              Cheese from whole cow milk                     16623.521739
#              Cream, fresh                                    2132.888889
#              Skim milk and whey powder                       3677.181818
# ...                                                                  ...
# 2019 Sweden  Cream, fresh                                    4557.800000
#              Skim milk and whey powder                       1688.083333
#              Whole milk powder                               1596.333333
#              Whole milk, condensed                            491.428571
#              Whole milk, evaporated                           466.857143
#
#
# Element                                                    Production
# Year Area    Item
# 2010 Austria Butter of cow milk                               33792.0
#              Cheese from milk of sheep, fresh or processed     1366.0
#              Cheese from whole cow milk                      156668.0
#              Cream, fresh                                     63927.0
#              Skim milk and whey powder                         6798.0
# ...                                                               ...
# 2019 Sweden  Cream, fresh                                     96860.0
#              Skim milk and whey powder                        42300.0
#              Whole milk powder                                34570.0
#              Whole milk, condensed                                NaN
#              Whole milk, evaporated                               NaN
#
# [2037 rows x 5 columns]

# %%
X1 = dft1.iloc[:, :4].values
Y1 = dft1.iloc[:, 4].values.reshape(-1,1)

# %%
print(np.shape(X1))
print(np.shape(Y1))
# Out:
# (2037, 4)
# (2037, 1)

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, test_size = .2, random_state=2021)

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state = 2019)

# %%
# make a dictionary of hyperparameter values to search
search_space = {
    "n_estimators" : [100, 200, 500],
    "max_depth" : [3, 6, 9],
    "gamma" : [0.01, 0.1],
    "learning_rate" : [0.001, 0.01, 0.1, 1]
}

# %%
from sklearn.model_selection import GridSearchCV
# make a GridSearchCV object
GS = GridSearchCV(estimator = xgb_model,
                  param_grid = search_space,
                  scoring = ["r2", "neg_root_mean_squared_error"], #sklearn.metrics.SCORERS.keys()
                  refit = "r2",
                  cv = 5,
                  verbose = 4)

# %%
GS.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.5s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.2s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.2s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.302) r2: (test=-0.290) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.166) r2: (test=-1.517) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.530) r2: (test=-3.654) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.432) r2: (test=-3.744) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.337) r2: (test=-0.688) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.290) r2: (test=-0.194) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.255) r2: (test=-4.946) total time=   0.3s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.429) r2: (test=-2.049) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.422) r2: (test=-3.535) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.342) r2: (test=-0.739) total time=   0.3s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.290) r2: (test=-0.194) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.255) r2: (test=-4.946) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.429) r2: (test=-2.049) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.422) r2: (test=-3.535) total time=   0.8s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.342) r2: (test=-0.739) total time=   0.7s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.301) r2: (test=-0.286) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.175) r2: (test=-1.791) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.519) r2: (test=-3.470) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.432) r2: (test=-3.744) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.348) r2: (test=-0.798) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.404) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.262) r2: (test=-5.260) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.424) r2: (test=-1.982) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.420) r2: (test=-3.485) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.358) r2: (test=-0.909) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.404) total time=   1.5s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.262) r2: (test=-5.260) total time=   1.7s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.424) r2: (test=-1.982) total time=   1.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.420) r2: (test=-3.485) total time=   1.5s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.358) r2: (test=-0.909) total time=   1.2s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.301) r2: (test=-0.286) total time=   0.1s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.175) r2: (test=-1.791) total time=   0.1s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.519) r2: (test=-3.470) total time=   0.1s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.432) r2: (test=-3.744) total time=   0.1s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.348) r2: (test=-0.798) total time=   0.1s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.404) total time=   0.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.262) r2: (test=-5.260) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.424) r2: (test=-1.982) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.420) r2: (test=-3.485) total time=   0.4s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.358) r2: (test=-0.909) total time=   0.5s
# [CV 1/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.404) total time=   1.4s
# [CV 2/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.262) r2: (test=-5.260) total time=   1.5s
# [CV 3/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.424) r2: (test=-1.982) total time=   1.3s
# [CV 4/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.420) r2: (test=-3.485) total time=   1.3s
# [CV 5/5] END gamma=0.01, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.358) r2: (test=-0.909) total time=   1.4s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.486) r2: (test=-2.351) total time=   0.2s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.239) r2: (test=-4.210) total time=   2.3s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.496) r2: (test=-3.077) total time=   0.8s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.466) r2: (test=-2.227) total time=   0.2s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.486) r2: (test=-2.351) total time=   0.5s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.239) r2: (test=-4.210) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.496) r2: (test=-3.077) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.466) r2: (test=-2.227) total time=   0.7s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.486) r2: (test=-2.351) total time=   1.1s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.239) r2: (test=-4.210) total time=   0.8s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.496) r2: (test=-3.077) total time=   1.1s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.9s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.466) r2: (test=-2.227) total time=   0.8s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   0.4s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   0.3s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.2s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   0.7s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   0.7s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.5s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   1.3s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   1.5s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   1.4s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   1.1s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   1.5s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   0.3s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   0.5s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   0.4s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.3s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   0.4s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   0.9s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   0.7s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   0.9s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   0.6s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   0.6s
# [CV 1/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.478) r2: (test=-2.240) total time=   1.5s
# [CV 2/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.232) r2: (test=-3.914) total time=   1.9s
# [CV 3/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.473) r2: (test=-2.711) total time=   2.4s
# [CV 4/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.448) r2: (test=-4.100) total time=   1.9s
# [CV 5/5] END gamma=0.01, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.472) r2: (test=-2.313) total time=   2.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1832.463) r2: (test=-47631247.834) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.565) r2: (test=-305669983.347) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1832.059) r2: (test=-55611988.447) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.813) r2: (test=-85354290.405) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-1831.823) r2: (test=-49954286.170) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1667.793) r2: (test=-39455368.814) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.398) r2: (test=-253026365.442) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.902) r2: (test=-46037262.520) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.651) r2: (test=-70656541.550) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-1666.661) r2: (test=-41352365.578) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1257.373) r2: (test=-22425893.823) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1254.999) r2: (test=-143514235.821) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.527) r2: (test=-26118077.214) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.264) r2: (test=-40080515.345) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.001, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-1255.274) r2: (test=-23457583.576) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-782.098) r2: (test=-8676480.604) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.186) r2: (test=-55321005.780) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.740) r2: (test=-10073686.758) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.463) r2: (test=-15454473.348) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-779.474) r2: (test=-9045014.814) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-303.822) r2: (test=-1309359.967) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.471) r2: (test=-8281326.818) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-302.052) r2: (test=-1511653.162) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.762) r2: (test=-2316281.763) total time=   0.2s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-301.773) r2: (test=-1355711.841) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.852) r2: (test=-4519.684) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.197) r2: (test=-26946.729) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.795) r2: (test=-5245.509) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.497) r2: (test=-7786.077) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.01, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-17.509) r2: (test=-4562.901) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.301) r2: (test=-0.287) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.187) r2: (test=-2.179) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.502) r2: (test=-3.168) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.390) r2: (test=-2.868) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.312) r2: (test=-0.448) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   0.9s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   1.0s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   1.0s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   1.0s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.301) r2: (test=-0.287) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.187) r2: (test=-2.179) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.502) r2: (test=-3.168) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.390) r2: (test=-2.868) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.312) r2: (test=-0.448) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   0.5s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   1.5s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   1.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   1.6s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   1.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   1.7s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.301) r2: (test=-0.287) total time=   0.1s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.187) r2: (test=-2.179) total time=   0.1s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.502) r2: (test=-3.168) total time=   0.1s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.390) r2: (test=-2.868) total time=   0.1s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.312) r2: (test=-0.448) total time=   0.1s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   0.6s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   0.7s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   0.5s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   0.5s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   0.5s
# [CV 1/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.315) r2: (test=-0.405) total time=   1.9s
# [CV 2/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.278) r2: (test=-6.018) total time=   1.6s
# [CV 3/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.418) r2: (test=-1.897) total time=   2.3s
# [CV 4/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.376) r2: (test=-2.595) total time=   1.7s
# [CV 5/5] END gamma=0.1, learning_rate=0.1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.296) r2: (test=-0.307) total time=   2.1s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.2s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.3s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=100; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.2s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.4s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=200; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.4s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   1.1s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   1.2s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   1.2s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   1.4s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=3, n_estimators=500; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.9s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.3s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.3s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.3s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=100; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.7s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.7s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.7s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=200; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.7s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   1.6s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   1.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   2.0s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   2.0s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=6, n_estimators=500; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   1.7s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.5s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.4s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.4s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.4s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=100; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.3s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   0.9s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   0.8s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   0.8s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   0.8s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=200; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   0.6s
# [CV 1/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.359) r2: (test=-0.830) total time=   2.4s
# [CV 2/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.280) r2: (test=-6.119) total time=   2.1s
# [CV 3/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.449) r2: (test=-2.336) total time=   2.4s
# [CV 4/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.463) r2: (test=-4.443) total time=   2.1s
# [CV 5/5] END gamma=0.1, learning_rate=1, max_depth=9, n_estimators=500; neg_root_mean_squared_error: (test=-0.401) r2: (test=-1.398) total time=   1.7s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=2019, ...),
#              param_grid={'gamma': [0.01, 0.1],
#                          'learning_rate': [0.001, 0.01, 0.1, 1],
#                          'max_depth': [3, 6, 9],
#                          'n_estimators': [100, 200, 500]},
#              refit='r2', scoring=['r2', 'neg_root_mean_squared_error'],
#              verbose=4)

# %%
# to get the complete details of the best model
print(GS.best_estimator_)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.1, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=3, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=2019, ...)

# %%
print(GS.best_params_) # to get only the best hyperparameter values that we searched for
# Out:
# {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}

# %%
print(GS.best_score_) # score according to the metric we passed in refit
# Out:
# -1.7899854181553454

# %%
df = pd.DataFrame(GS.cv_results_)
df = df.sort_values("rank_test_r2")
df.to_csv("cv_results.csv", index = False)

# %%
from dotenv import dotenv_values

config = dotenv_values(".env")

# %%
from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %%
import re
import string
from string import punctuation
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')


import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
tweets = pd.read_csv('tweets.csv')

for tweet in tweets:
    print(tweets)
    analysis = TextBlob(tweet)
    print(analysis.sentiment)
    if analysis.sentiment[0]>0:
       print ('Positive')
    elif analysis.sentiment[0]<0:
       print ('Negative')
    else:
       print ('Neutral')

# %%
client = tweepy.Client("AAAAAAAAAAAAAAAAAAAAAKAllAEAAAAAFVWYkFjqgPPtg3jI5WrxFld9shk%3DjFdrHRwAVjXTmeFpFznF0KeYJQJUZGxAA1g4ejUiWpqbQpsCVf")

query = 'price of milk -is:retweet lang:en OR cost of milk -is:retweet lang:en OR cost of dairy -is:retweet lang:en OR price of dairy -is:retweet lang:en',
tweets = tweepy.Paginator(client.search_recent_tweets, query=query,
                             tweet_fields=['context_annotations','created_at'], max_results=100).flatten(limit=1500)

#for tweet in tweets:
    #tweet_list.append(tweets.csv)
    
tweets = pd.DataFrame(tweets, columns=['full_text'])
tweets

# %%
tweets = pd.read_csv('tweets.csv')
tweets.head()

# %%
tweets = tweets.drop(['Unnamed: 0', ], axis=1)
tweets.dropna(inplace=True)

# %% [markdown]
# ## Statistics time

# %% [markdown]
# t-test: A t-test is used to compare the means of two groups. It can be used to determine whether the means of two groups are significantly different from each other.
#
# ANOVA: Analysis of variance (ANOVA) is used to compare the means of three or more groups. It can be used to determine whether the means of the groups are significantly different from each other.
#
# Chi-square test: A chi-square test is used to compare observed data to expected data. It is often used to determine whether there is a significant relationship between two categorical variables.
#
# Pearson's correlation coefficient: Pearson's correlation coefficient is used to measure the strength and direction of the relationship between two continuous variables. It can be used to determine whether there is a significant relationship between the variables.
#
# Linear regression: Linear regression is used to predict the value of a continuous outcome variable based on the value of one or more predictor variables. It can be used to determine the strength and direction of the relationship between the predictor and outcome variables.

# %%
stratify_col = 'Item'

# Group the data by the stratifying column
grouped = df.groupby(stratify_col)

# Pick a random sample of 50 rows from each group
sample = grouped.apply(lambda x: x.sample(n=7, random_state=42))

# Reset the index of the resulting DataFrame
sample = sample.reset_index(drop=True)

# Print the sample
sample.head(50)

# %%
from scipy.stats import normaltest

numerical_data = product.select_dtypes(include=['float', 'int'])

# Calculate the test statistic and p-value for each numerical column
for column in numerical_data:
    statistic, pvalue = normaltest(numerical_data[column])
    print(f"Column: {column}")
    print(f"Test statistic: {statistic}")
    print(f"P-value: {pvalue}")
    if pvalue < 0.05:
        print("The data is not normally distributed.")
    else:
        print("The data is normally distributed.")

# %%
from scipy.stats import ttest_ind

# define the two groups of data
group_1 = transaction.loc[transaction['Country'] == 'Europe', 'Value']
group_2 = transaction.loc[transaction['Country'] == 'Ireland', 'Value']


# perform the t-test
t_statistic, p_value = ttest_ind(group_1, group_2)

# print the t-statistic and p-value
print(t_statistic)
print(p_value)

# Determine if the differences between the groups are significant
if p_value < 0.05:
    print("There is a significant difference between the means of the groups.")
else:
    print("There is no significant difference between the means of the groups.")

# %%
from scipy.stats import f_oneway

export_data = transaction.loc[transaction['Element'] == 'Export Value']

# Add some data for two groups
group1 = export_data.loc[transaction['Area'] == 'France', 'Value']
group2 = export_data.loc[transaction['Area'] == 'Ireland', 'Value']
group3 = export_data.loc[transaction['Area'] == 'Germany', 'Value']

# Perform the ANOVA test
statistic, pvalue = f_oneway(group1, group2, group3)

# Print the results
print("F-value:", statistic)
print("P-value:", pvalue)

# Determine if the differences between the groups are significant
if pvalue < 0.05:
    print("There is a significant difference between the means of the groups.")
else:
    print("There is no significant difference between the means of the groups.")

# %%
from scipy.stats import mannwhitneyu

# Perform the Mann-Whitney U test
statistic, pvalue = mannwhitneyu(group1, group2)

print(statistic)
print(pvalue)

# Determine if the differences between the groups are significant
if pvalue < 0.05:
    print("There is a significant difference between the means of the groups.")
else:
    print("There is no significant difference between the means of the groups.")

# %%
from scipy.stats import friedmanchisquare

# Perform the Wilcoxon signed-rank test
statistic, pvalue = friedmanchisquare(group1, group2, group3)

print(statistic)
print(pvalue)

# Determine if the differences between the groups are significant
if pvalue > 0.05:
    print("There is a significant difference between the means of the groups.")
else:
    print("There is no significant difference between the means of the groups.")

# %%
transaction.head()

# %% [markdown]
# # Machine Learning
#
# I opted to go for the following models -
# 1. Decision Tree
#
# 2. KNN Nearest neighbour
#
# 3. Sentiment Analysis

# %% [markdown]
# ## KNN Nearest neighbour

# %%
# One hot encode the categorical column
one_hot_encoded = pd.get_dummies(transaction, columns=['Item'])

# Concatenate the one hot encoded column to the original DataFrame
df = pd.concat([transaction, one_hot_encoded], axis=1)

# Drop the original categorical column
transaction.drop(['Item'], axis=1, inplace=True)

# %%
transaction.head()

# %%
one_hot_encoded.drop(['Area', 'Element', 'Year', 'Unit', 'Flag Description', 'Country', 'id'], axis=1, inplace=True)
one_hot_encoded.head()

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_label,test_label = train_test_split(one_hot_encoded.iloc[:,:9], 
                                                                one_hot_encoded.iloc[:,6], test_size=0.2, random_state=42)

# %%
train_data.shape,train_label.shape,test_data.shape,test_label.shape

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neighbors = np.arange(1, 5)                  # number of neighbors
train_accuracy = np.zeros(len(neighbors))    # Declare and initialise the matrix
test_accuracy = np.zeros(len(neighbors))     # Declare and initialise the matrix

# %%
for i,k in enumerate(neighbors):                          # for loop that checks the model for neighbor values 1, 2, 3, ..., 9
    knn = KNeighborsClassifier(n_neighbors = k)           # Initialise an object knn using KNeighborsClassifier method

    #Fit the model
    knn.fit(train_data, train_label)                      # Call fit method to implement the ML KNeighborsClassifier model

    #Compute accuracy on the training set
    train_accuracy[i] = knn.score(train_data, train_label)   # Save the score value in the train_accuracy array

    #Compute accuracy on the test set
    test_accuracy[i] = knn.score(test_data, test_label)      # Save the score value in the train_accuracy array

# %%
# Delcare the size of the array
plt.figure(figsize = (10, 6))
plt.title('KNN accuracy with varying number of neighbors', fontsize = 20)
plt.plot(neighbors, test_accuracy, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training accuracy')
plt.legend(prop = {'size': 20})
plt.xlabel('Number of neighbors', fontsize = 20)
plt.ylabel('Accuracy', fontsize = 20)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %%
# Declare and initialise an object 'KNeighborsClassifier' with 3 neighbors
knn = KNeighborsClassifier(n_neighbors = 3)

# Fit the model
knn.fit(train_data, train_label)

# Compute accuracy on the training set
train_accuracy = knn.score(train_data, train_label)

# Compute accuracy on the test set
test_accuracy = knn.score(test_data, test_label)

# %%
# Display the test accuracy
print(test_accuracy)

# %%
# import the library classification_report
from sklearn.metrics import classification_report

# Display the report
print(classification_report(test_label, prediction))

# %%
product.head()

# %%
# One hot encode the categorical column
prod_enc = pd.get_dummies(product, columns=['Item'])

# Concatenate the one hot encoded column to the original DataFrame
df = pd.concat([product, prod_enc], axis=1)

prod_enc.drop(['Area', 'Unit', 'Flag Description', 'id', 'Country'], axis=1, inplace=True)
prod_enc.head()

# %%
X = prod_enc.iloc[:, [2, 3]].values
y = prod_enc.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(max_depth = 5, random_state = 0)
classifier.fit(X_train, y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Calculate cm by calling a method named as 'confusion_matrix'
cm = confusion_matrix(y_test, y_pred)

# Call a method heatmap() to plot confusion matrix
sns.heatmap(cm, annot = True)

# print the classification_report based on y_test and y_predict
print(classification_report(y_test, y_pred))

# %%
from sklearn import metrics                           # Import scikit-learn metrics module for accuracy calculation
import warnings
warnings.filterwarnings('ignore') # We can suppress the warnings

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (4,4), dpi=300)

from sklearn import tree

tree.plot_tree(classifier.fit(X_train, y_train))

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Decision Tree Classification (Training set)')
plt.xlabel('Europe')
plt.ylabel('Ireland')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Decision Tree Classification (Test set)')
plt.xlabel('Europe')
plt.ylabel('Ireland')
plt.legend()
plt.show()

# %%
dprodtransaction.loc[transaction['Country'] == 'Europe']
idea = pd.crosstab(df["Year"], dprod["Item"])

# %%
result_crosstab = pd.crosstab(index = product["Item"], 
                              columns=product["Element"], 
                              values = product["Value"], 
                              aggfunc=np.mean)
                              
sns.heatmap(result_crosstab, annot = True, fmt = 'g')

# %%
idea.head()

# %%
sns.heatmap(idea, annot=True)

# %%
idx = ["Element"]
d = pd.melt(diev, id_vars=idx)
idea2 = pd.crosstab(diev.Element, diev.Item, diev.Value, aggfunc="mean", rownames=idx, colnames=[None])

# %%
diev.groupby('Element', as_index=False).mean()

# %%
idea2.head()

# %%
idea2.describe()

# %%
group2 = idea2.groupby('Element' == '')['Element']

corelation = group2.corr()

sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

plt.show()
